# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from ryu_tool import mytool
from ryu_tool.min_variance import PortfolioOptimzer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9836\84623018.py in <module>
#       3 import matplotlib.pyplot as plt
#       4 from ryu_tool import mytool
# ----> 5 from ryu_tool.min_variance import PortfolioOptimzer
#
# ModuleNotFoundError: No module named 'ryu_tool.min_variance'

# %%
# 필요한 파일을 불러옵니다
etfs = pd.read_csv("Data/ETF.csv",
                   index_col=0,
                   parse_dates=True).dropna()

# %%
etfs.columns  = ["VTI", "TLT", "SHY", "GLD", "GSG", "VNQ"]

# %%
portfolio = PortfolioOptimzer(price=etfs)

# %%
linear_weight = portfolio.run_optimizer(start_year="2007",
                                      end_year="2023",
                                      rebalancing="Q",
                                      shrinkage_method="None",
                                      lo
                                      args="None")
# Out:
# 100%|██████████| 192/192 [00:00<00:00, 323.21it/s]
# Jobs Done...
# You can check .rebalancing_date

# %%
a,b = mytool.simulate_rebalancing(portfolio.rtn, 
                                  linear_weight)

# %%
pd.Series(a).plot(figsize=(24,12));

# %%
b.plot(figsize=(24,12));
